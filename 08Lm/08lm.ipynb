# %% [markdown]
# # ESCUELA POLITECNICA NACIONAL
#
# - Nombre: Freddy Jiménez
# - Fecha: 10/06/2026

# %% [markdown]
# ## PRACTICA DE CONEXION DE API DE GEMINI AL PYTHON VISUAL....

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.17)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (48.0.1)
# Requirement already satisfied: certifi in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\freddy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\FREDDY\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
apy_key = "YOUR_API_KEY"

# %%
from google import genai

API_KEY = apy_key

client = genai.Client(api_key=API_KEY)

# Usa el nombre EXACTO como aparece en la lista: 'models/gemini-2.5-flash'
response = client.models.generate_content(
    model='models/gemini-2.5-flash',  # ← Con "models/" al inicio
    contents='Cuando son las matriculas?'
)

print(response.text)
# Out:
# Las fechas de matrícula **dependen mucho** de varios factores:
#
# 1.  **Tipo de estudios/institución:**
#     *   **Universidad (Grado):**
#         *   **Periodo principal:** Generalmente, las matrículas para el curso académico que empieza en septiembre suelen abrirse tras las pruebas de acceso a la universidad (EBAU/EVAU/PAU en España, o exámenes de admisión en otros países) y la publicación de las notas de corte. Esto suele ser **desde finales de julio, todo el mes de agosto y principios de septiembre**, con varias fases de adjudicación de plazas.
#         *   **Másteres y Postgrados:** Pueden tener calendarios más variados, algunos abren sus preinscripciones mucho antes (incluso en primavera) y las matrículas definitivas en verano, o tienen periodos específicos a lo largo del año.
#     *   **Formación Profesional (FP):** Similar a la universidad, suele ser en verano (julio-septiembre) tras la publicación de los resultados de admisión.
#     *   **Colegios e Institutos (Educación Infantil, Primaria, ESO, Bachillerato):**
#         *   **Nuevas admisiones (para el siguiente curso):** El proceso de preinscripción y solicitud de plaza suele ser mucho antes, a menudo entre **febrero y abril**. La matrícula definitiva para los alumnos admitidos suele ser en **junio o julio**.
#         *   **Alumnos que continúan:** A menudo es un proceso automático o una simple confirmación de matrícula en **junio o julio**.
#     *   **Academias, Escuelas de Idiomas, Cursos específicos:** Suelen tener matriculaciones continuas o vinculadas al inicio de cada curso/trimestre.
#
# 2.  **País y Comunidad Autónoma/Región:** Las fechas exactas pueden variar significativamente entre países y, dentro de un mismo país, entre diferentes regiones o incluso entre universidades o centros educativos.
#
# **Para saber las fechas exactas que te interesan, lo más recomendable es:**
#
# *   **Consultar la página web oficial** de la universidad, centro de estudios, ministerio de educación o consejería de educación de tu región.
# *   **Revisar el "Calendario Académico Oficial"** de la institución.
# *   **Contactar directamente con la secretaría o el departamento de admisiones** del centro.
#
# ¿Podrías especificar qué tipo de matrícula te interesa y en qué país o región? Así podría darte una respuesta más precisa.

# %%
contents = ['En mi facultad tenemos 4 carreras, la carrera de ingenieria en computacion, ingenieria en software, ingenieria en ciencias de datos e ingenieria en sistemas de la infomacion',
'Las matriculas para el proximo comienzan el 1 de julio y termina el 15 de julio. Es importante que los estudiantes se matriculen a tiempo para asegurar su lugar en las clases y evitar retrasos en el proceso académico.',
'Las matriculas de computacion y software son el 1 de julio, las matriculas de ciencias de datos son el 5 de julio y las matriculas de sistemas de la informacion son el 10 de julio.',
'Para los estudiantes especiales las matriculas son del 11 al 15 de julio.',
'Cuando son las matriculas?']

# %%
response = client.models.generate_content(
    model='models/gemini-2.5-flash',  # ← Con "models/" al inicio
    contents=contents
)

# %%
print (response.text)
# Out:
# Aquí tienes el resumen de las fechas de matrícula:
#
# *   **Periodo General de Matrículas:** Del **1 de julio al 15 de julio**.
#
# *   **Por Carrera:**
#     *   **Ingeniería en Computación:** 1 de julio
#     *   **Ingeniería en Software:** 1 de julio
#     *   **Ingeniería en Ciencias de Datos:** 5 de julio
#     *   **Ingeniería en Sistemas de la Información:** 10 de julio
#
# *   **Estudiantes Especiales:** Del **11 al 15 de julio**.
